# %% [markdown]
# <a href="https://colab.research.google.com/github/Serbeld/Practicas-de-Python/blob/master/Series_de_tiempo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
from time import sleep
import pandas as pd

# Se importan las librerias

from google.colab import drive
drive.mount('/content/drive')
sys.path.append('/content/drive/My Drive/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Se lee el archivo CSV con la libreria pandas
Archivo = pd.read_csv('/content/drive/My Drive/SerieDeTiempo.csv')

# %%
# Se leen los valores de voltaje y tiempo en nanosegundos
voltajes = Archivo['Voltaje'].values
tiempo = Archivo['Tiempo'].values

# %%
# Se toman los primeros 7940 datos
voltajes = voltajes[0:7940]
tiempo = tiempo[0:7940]

# %%
# Se toman vectores de inicializacion
picosdevoltaje = []
tiempodeplotinicial = []
tiempodeplot = []

# Inicia el intervalo de la toma de datos a plotear en cero
puntoinicio = 0

# Contador auxiliar
contador = 0

# Contador de pulsos obtenidos
pulsos = 0

# Lista auxiliar
listaactual = []

# Almacena en tiempodeplotincial todos los valores de tiempo encontrados
for i in range(0,len(tiempo)):
  if str(tiempo[i]) != 'nan':
    tiempodeplotinicial.append(int(tiempo[i]))

# %%
# Almacena todos los valores de voltaje encontrados 
for i in range(0,len(voltajes)):
  if voltajes[i] != '#':
    picosdevoltaje.append((voltajes[i]))
    contador = contador + 1

    # cuenta el numero de pulsos que se dan cada 12 valores de voltaje
    if contador == 12:
      pulsos = pulsos + 1

  else:
    contador = 0

# %%
print(picosdevoltaje)
# Out:
# ['50', '50', '143', '354', '260', '150', '72', '94', '58', '99', '54', '51', '51', '51', '109', '91', '73', '52', '51', '72', '49', '51', '53', '50', '50', '50', '938', '328', '128', '118', '87', '65', '62', '49', '71', '50', '50', '50', '174', '101', '50', '61', '91', '50', '49', '49', '50', '49', '50', '51', '631', '251', '139', '137', '87', '62', '50', '50', '46', '48', '50', '51', '778', '445', '199', '158', '106', '110', '106', '48', '48', '50', '50', '50', '98', '102', '131', '65', '69', '50', '50', '49', '51', '47', '50', '49', '258', '257', '120', '170', '79', '71', '61', '48', '50', '56', '49', '50', '768', '462', '162', '110', '168', '79', '59', '49', '50', '50', '49', '72', '176', '85', '127', '58', '55', '50', '51', '49', '70', '50', '49', '50', '311', '265', '151', '104', '101', '72', '50', '53', '50', '50', '52', '50', '125', '78', '49', '50', '49', '50', '49', '50', '49', '51', '50', '50', '354', '203', '131', '61', '120', '52', '76', '48', '48', '50', '50', '58', '636', '259', '233', '162', '110', '66', '75', '55', '48', '50', '51', '50', '83', '183', '161', '82', '82', '55', '64', '65', '50', '52', '51', '73', '249', '241', '138', '82', '113', '48', '53', '50', '68', '51', '50', '50', '288', '205', '96', '51', '48', '50', '57', '48', '50', '49', '48', '50', '148', '204', '128', '148', '53', '75', '66', '53', '50', '50', '49', '48', '376', '191', '190', '138', '87', '48', '61', '46', '51', '73', '49', '50', '475', '364', '139', '203', '56', '59', '54', '53', '47', '52', '50', '50', '234', '166', '123', '47', '63', '87', '50', '50', '50', '50', '50', '50', '97', '97', '122', '45', '53', '85', '62', '50', '51', '53', '51', '51', '657', '424', '121', '94', '148', '76', '83', '58', '63', '50', '51', '51', '596', '284', '161', '102', '85', '85', '73', '50', '55', '48', '50', '50', '663', '236', '157', '139', '110', '59', '57', '51', '57', '52', '49', '50', '722', '321', '186', '152', '113', '54', '71', '72', '48', '50', '50', '49', '174', '126', '66', '108', '88', '49', '51', '67', '50', '49', '50', '50', '268', '118', '121', '54', '65', '50', '61', '50', '49', '50', '50', '50', '602', '298', '256', '113', '103', '97', '96', '57', '50', '53', '50', '53', '498', '256', '137', '115', '54', '48', '49', '52', '48', '49', '49', '54', '591', '265', '277', '91', '52', '78', '49', '50', '49', '49', '50', '49', '160', '87', '65', '57', '51', '67', '58', '51', '50', '50', '50', '51', '663', '542', '184', '119', '59', '90', '63', '49', '50', '50', '49', '64', '290', '146', '91', '84', '45', '56', '67', '50', '49', '51', '50', '54', '115', '63', '78', '51', '53', '49', '49', '50', '50', '49', '50', '51', '581', '209', '129', '110', '54', '52', '52', '67', '54', '49', '51', '51', '328', '508', '261', '194', '116', '96', '139', '47', '54', '51', '67', '49', '92', '71', '47', '50', '49', '49', '50', '49', '48', '49', '49', '49', '644', '318', '218', '137', '101', '121', '51', '53', '51', '49', '49', '50', '137', '141', '115', '66', '52', '48', '49', '50', '48', '49', '48', '48', '257', '139', '164', '77', '61', '112', '46', '50', '49', '48', '50', '50', '155', '63', '133', '75', '46', '46', '52', '50', '68', '49', '52', '50', '94', '451', '166', '276', '75', '55', '51', '49', '50', '51', '50', '50', '86', '70', '61', '49', '49', '50', '50', '50', '49', '50', '51', '50', '310', '145', '108', '55', '50', '57', '52', '51', '50', '51', '50', '77', '452', '206', '159', '116', '59', '55', '67', '53', '50', '48', '50', '62', '323', '185', '182', '162', '125', '49', '52', '51', '53', '51', '50', '51', '97', '57', '50', '50', '50', '50', '50', '50', '50', '50', '51', '50', '80', '69', '53', '76', '53', '77', '50', '50', '51', '50', '50', '50', '170', '68', '63', '53', '51', '51', '66', '50', '51', '53', '49', '49', '118', '418', '245', '127', '67', '78', '50', '50', '49', '51', '49', '50', '681', '366', '273', '73', '71', '67', '54', '50', '65', '60', '49', '51', '1023', '573', '289', '166', '122', '58', '66', '143', '48', '63', '50', '50' ...

# %%
for i in range(0,pulsos):
  listaactual = np.linspace(puntoinicio, int(tiempodeplotinicial[i]), num = 12)
  puntoinicio = int(tiempodeplotinicial[i])
  tiempodeplot.extend(listaactual)

# %%
#Convierte la fecha

#!pip install datetime
from datetime import datetime
#Fecha
fecha = 1558162800

textodelafecha = str(datetime.utcfromtimestamp(fecha).strftime('%Y-%m-%d'))

print(textodelafecha)
# Out:
# 2019-05-18

# %%
tiempodeploteado = tiempodeplot[0:len(tiempodeplot)]
voltajeploteado = picosdevoltaje[0:len(picosdevoltaje)]

# Graficar
plt.figure(1, figsize= [7.4,6])  
plt.plot(tiempodeploteado,voltajeploteado,'b',linewidth=1)   
plt.xlabel("Tiempo (nS)",fontsize = 'xx-large')  
plt.ylabel("Voltaje (V)",fontsize = 'xx-large')    
plt.title("Serie de tiempo",fontsize = 'xx-large')  
plt.legend([textodelafecha],fontsize = 'x-large')
plt.grid(color='b', ls = '-.', lw = 0.2)

plt.show()

# %%
tiempodeploteado = tiempodeplot[0:int(1000)]
voltajeploteado = picosdevoltaje[0:int(1000)]

# Graficar
plt.figure(2, figsize= [7.4,6])  
plt.plot(tiempodeploteado,voltajeploteado,'b',linewidth=2)  
plt.xlabel("Tiempo (nS)",fontsize = 'xx-large')  
plt.ylabel("Voltaje (V)",fontsize = 'xx-large')   
plt.title("Serie de tiempo",fontsize = 'xx-large')  
plt.legend([textodelafecha],fontsize = 'x-large')
plt.grid(color='b', ls = '-.', lw = 0.2)

plt.show()

# %%
tiempodeploteado = tiempodeplot[0:int(100)]
voltajeploteado = picosdevoltaje[0:int(100)]

# Graficar
plt.figure(3, figsize= [7.4,6])  
plt.plot(tiempodeploteado,voltajeploteado,'b',linewidth=4)  
plt.xlabel("Tiempo (nS)",fontsize = 'xx-large')  
plt.ylabel("Voltaje (V)",fontsize = 'xx-large')  
plt.title("Serie de tiempo",fontsize = 'xx-large')  
plt.legend([textodelafecha],fontsize = 'x-large')
plt.grid(color='b', ls = '-.', lw = 0.2)

plt.show()
